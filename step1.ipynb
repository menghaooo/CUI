# %%
import pandas as pd
df=pd.read_csv('/Users/fufuyi/Desktop/python/result.CSV')
df
# Out:
# Empty DataFrame
# Columns: [sclk, uttime, target, time_ca, targ_pos_x, targ_pos_y, targ_pos_z, source, data_reliability, table_set_id, coadd_cnt, osp_fil_1_status, oss_fil_2_status, csp_fil_3_status, css_fil_4_status, seq_table, cyc_num, cyc_table, scan_num, trap_table, sw_table, mass_table, focus_table, da_table, velocity_comp, ipnum, mass_per_charge, os_lens2, os_lens1, os_lens4, os_lens3, qp_lens2, qp_lens1, qp_lens4, qp_lens3, qp_bias, ion_defl2, ion_defl1, ion_defl4, ion_defl3, top_plate, p_energy, alt_t, view_dir_t_x, view_dir_t_y, view_dir_t_z, sc_pos_t_x, sc_pos_t_y, sc_pos_t_z, sc_vel_t_x, sc_vel_t_y, sc_vel_t_z, sc_vel_t_scx, sc_vel_t_scy, sc_vel_t_scz, lst_t, sza_t, ss_long_t, distance_s, view_dir_s_x, view_dir_s_y, view_dir_s_z, sc_pos_s_x, sc_pos_s_y, sc_pos_s_z, sc_vel_s_x, sc_vel_s_y, sc_vel_s_z, lst_s, sza_s, ss_long_s, sc_att_angle_ra, sc_att_angle_dec, sc_att_angle_tw, c1counts, c2counts]
# Index: []
#
# [0 rows x 76 columns]

# %%
import pandas as pd
df=pd.read_csv('/Users/fufuyi/Desktop/INMS/2006/001_031_JAN/001/200600100_L1A_05.CSV')
df
# Out:
#                        sclk       uttime  target       time_ca  \
# 0                       NaN           ms     NaN            ms
# 1                      sclk  uttime (ms)  target  time_ca (ms)
# 2     2006-001T00:00:10.054        10054     NaN           NaN
# 3     2006-001T00:00:10.088        10088     NaN           NaN
# 4     2006-001T00:00:10.122        10122     NaN           NaN
# 5     2006-001T00:00:10.156        10156     NaN           NaN
# 6     2006-001T00:00:10.190        10190     NaN           NaN
# 7     2006-001T00:00:10.224        10224     NaN           NaN
# 8     2006-001T00:00:10.258        10258     NaN           NaN
# 9     2006-001T00:00:10.292        10292     NaN           NaN
# 10    2006-001T00:00:10.326        10326     NaN           NaN
# 11    2006-001T00:00:10.360        10360     NaN           NaN
# 12    2006-001T00:00:10.394        10394     NaN           NaN
# 13    2006-001T00:00:10.428        10428     NaN           NaN
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/Users/fufuyi/Desktop/INMS/2006/244_273_SEP/252/200625216_L1A_05.CSV')
df1=df.drop([0,1],axis=0)
df1.index=np.arange(0,len(df)-2,1)
df1
# Out:
#                        sclk    uttime target   time_ca targ_pos_x targ_pos_y  \
# 0     2006-252T15:59:44.494  57584494    NaN       NaN        NaN        NaN
# 1     2006-252T15:59:44.528  57584528    NaN       NaN        NaN        NaN
# 2     2006-252T15:59:44.562  57584562    NaN       NaN        NaN        NaN
# 3     2006-252T15:59:44.596  57584596    NaN       NaN        NaN        NaN
# 4     2006-252T15:59:44.630  57584630    NaN       NaN        NaN        NaN
# 5     2006-252T15:59:44.664  57584664    NaN       NaN        NaN        NaN
# 6     2006-252T15:59:44.698  57584698    NaN       NaN        NaN        NaN
# 7     2006-252T15:59:44.732  57584732    NaN       NaN        NaN        NaN
# 8     2006-252T15:59:44.766  57584766    NaN       NaN        NaN        NaN
# 9     2006-252T15:59:44.800  57584800    NaN       NaN        NaN        NaN
# 10    2006-252T15:59:44.834  57584834    NaN       NaN        NaN        NaN
# ...

# %%
MIMAS=df1.dropna(subset=["target"])[df1.target=="MIMAS"]
ENCELADUS=df1.dropna(subset=["target"])[df1.target=="ENCELADUS"]
TETHYS=df1.dropna(subset=["target"])[df1.target=="TETHYS"]
DIONE=df1.dropna(subset=["target"])[df1.target=="DIONE"]
RHEA=df1.dropna(subset=["target"])[df1.target=="RHEA"]
TITAN=df1.dropna(subset=["target"])[df1.target=="TITAN"]
HYPERION=df1.dropna(subset=["target"])[df1.target=="HYPERION"]
LAPETUS=df1.dropna(subset=["target"])[df1.target=="LAPETUS"]
PHOEBE=df1.dropna(subset=["target"])[df1.target=="PHOEBE"]
JANUS=df1.dropna(subset=["target"])[df1.target=="JANUS"]
EPIMETHEUS=df1.dropna(subset=["target"])[df1.target=="EPIMETHEUS"]
HELENE=df1.dropna(subset=["target"])[df1.target=="HELENE"]
TELESTO=df1.dropna(subset=["target"])[df1.target=="TELESTO"]
CALYPSO=df1.dropna(subset=["target"])[df1.target=="CALYPSO"]
ATLAS=df1.dropna(subset=["target"])[df1.target=="ATLAS"]
PROMETHEUS=df1.dropna(subset=["target"])[df1.target=="PROMETHEUS"]
PANDORA=df1.dropna(subset=["target"])[df1.target=="PANDORA"]
PAN=df1.dropna(subset=["target"])[df1.target=="PAN"]

# %%
MIMAS.to_csv("/Users/fufuyi/Desktop/step1/MIMAS.CSV",index_label=False)
ENCELADUS.to_csv("/Users/fufuyi/Desktop/step1/ENCELADUS.CSV",index_label=False)
TETHYS.to_csv("/Users/fufuyi/Desktop/step1/TETHYS.CSV",index_label=False)
DIONE.to_csv("/Users/fufuyi/Desktop/step1/DIONE.CSV",index_label=False)
RHEA.to_csv("/Users/fufuyi/Desktop/step1/RHEA.CSV",index_label=False)
TITAN.to_csv("/Users/fufuyi/Desktop/step1/TITAN.CSV",index_label=False)
HYPERION.to_csv("/Users/fufuyi/Desktop/step1/HYPERION.CSV",index_label=False)
LAPETUS.to_csv("/Users/fufuyi/Desktop/step1/LAPETUS.CSV",index_label=False)
PHOEBE.to_csv("/Users/fufuyi/Desktop/step1/PHOEBE.CSV",index_label=False)
JANUS.to_csv("/Users/fufuyi/Desktop/step1/JANUS.CSV",index_label=False)
EPIMETHEUS.to_csv("/Users/fufuyi/Desktop/step1/EPIMETHEUS.CSV",index_label=False)
HELENE.to_csv("/Users/fufuyi/Desktop/step1/HELENE.CSV",index_label=False)
TELESTO.to_csv("/Users/fufuyi/Desktop/step1/TELESTO.CSV",index_label=False)
CALYPSO.to_csv("/Users/fufuyi/Desktop/step1/CALYPSO.CSV",index_label=False)
PROMETHEUS.to_csv("/Users/fufuyi/Desktop/step1/PROMETHEUS.CSV",index_label=False)
PANDORA.to_csv("/Users/fufuyi/Desktop/step1/PANDORA.CSV",index_label=False)
PAN.to_csv("/Users/fufuyi/Desktop/step1/PAN.CSV",index_label=False)
